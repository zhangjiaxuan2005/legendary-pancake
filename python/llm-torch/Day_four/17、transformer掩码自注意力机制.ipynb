# %% [markdown]
# ## 掩码自注意力机制

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 10
#       8 remove_imported_pydev_package()
#       9 import pydev_jupyter_utils
# ---> 10 pydev_jupyter_utils.attach_to_debugger(25348)
#
# File D:\Program Files\JetBrains\PyCharm\plugins\python-ce\helpers\jupyter_debug\pydev_jupyter_utils.py:76, in attach_to_debugger(debugger_port)
#      73 def attach_to_debugger(debugger_port):
#      74     ipython_shell = get_ipython()
# ---> 76     import pydevd
#      77     from _pydev_bundle import pydev_localhost
#      79     debugger = pydevd.PyDB()
#
# File D:\Program Files\JetBrains\PyCharm\plugins\python-ce\helpers\pydev\pydevd.py:64
#      59 from _pydevd_bundle.pydevd_trace_dispatch import (
#      60     trace_dispatch as _trace_dispatch, show_tracing_warning)
#      61 from _pydevd_frame_eval.pydevd_frame_eval_main import (
# ...
